# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### read data

# %%
import pandas as pd

# %%
trump_tweets = pd.read_csv('../data/RAW_trump_tweets_20160101_20200930.csv', parse_dates=['created_at'])
trump_tweets.head()
# Out:
#                source                                               text  \
# 0  Twitter for iPhone  I won the debate big based on compilation of p...
# 1  Twitter for iPhone  Thank you @HerschelWalker! https://t.co/XjlYe8...
# 2  Twitter for iPhone  RT @GOPChairwoman: Big news!A Maine court side...
# 3  Twitter for iPhone            Thank you Paul! https://t.co/aAk1sfww0d
# 4  Twitter for iPhone  100000 DEFECTIVE BALLOTS IN NEW YORK. THEY WAN...
#
#            created_at  retweet_count  favorite_count is_retweet  \
# 0 2020-10-01 15:14:28          44961          337926      False
# 1 2020-10-01 03:45:25          19616           65721      False
# 2 2020-10-01 03:25:31          29393               0       True
# 3 2020-10-01 03:00:33          15992           63294      False
# 4 2020-10-01 02:59:02          51445          190750      False
#
#                 id_str
# 0  1311685923097260034
# 1  1311512518800470016
# 2  1311507509958471680
# 3  1311501225423073281
# 4  1311500843309387781

# %%
trump_tweets.dtypes
# Out:
# source                    object
# text                      object
# created_at        datetime64[ns]
# retweet_count              int64
# favorite_count             int64
# is_retweet                object
# id_str                     int64
# dtype: object

# %% [markdown]
# ### convert GMT into US Eastern timezone

# %%
import datetime
import pytz

# %%
gmt = pytz.timezone('GMT')
us_eastern = pytz.timezone('US/Eastern')

# %%
def convert_to_us_eastern(row):
    date = row['created_at']
    date_gmt = gmt.localize(date)
    date_us_eastern = date_gmt.astimezone(us_eastern).tz_localize(None) # remove tz info to obtain naive local time
    return date_us_eastern

# %%
trump_tweets['created_at'] = trump_tweets.apply(convert_to_us_eastern, axis=1)

# %%
trump_tweets.head()
# Out:
#                source                                               text  \
# 0  Twitter for iPhone  I won the debate big based on compilation of p...
# 1  Twitter for iPhone  Thank you @HerschelWalker! https://t.co/XjlYe8...
# 2  Twitter for iPhone  RT @GOPChairwoman: Big news!A Maine court side...
# 3  Twitter for iPhone            Thank you Paul! https://t.co/aAk1sfww0d
# 4  Twitter for iPhone  100000 DEFECTIVE BALLOTS IN NEW YORK. THEY WAN...
#
#            created_at  retweet_count  favorite_count is_retweet  \
# 0 2020-10-01 11:14:28          44961          337926      False
# 1 2020-09-30 23:45:25          19616           65721      False
# 2 2020-09-30 23:25:31          29393               0       True
# 3 2020-09-30 23:00:33          15992           63294      False
# 4 2020-09-30 22:59:02          51445          190750      False
#
#                 id_str
# 0  1311685923097260034
# 1  1311512518800470016
# 2  1311507509958471680
# 3  1311501225423073281
# 4  1311500843309387781

# %% [markdown]
# ### filter tweets from 1 Jan 2016 to 30 Sep 2020

# %%
start_date = datetime.datetime.strptime('2016-01-01', '%Y-%m-%d')
end_date = datetime.datetime.strptime('2020-09-30', '%Y-%m-%d')

# %%
trump_tweets = trump_tweets[(trump_tweets.created_at >= start_date) & (trump_tweets.created_at <= end_date)]

# %%
trump_tweets
# Out:
#                     source                                               text  \
# 69      Twitter for iPhone                            https://t.co/HUSFkHqsyC
# 70      Twitter for iPhone  RT @TyCardon: Regardless who you’re pulling fo...
# 71      Twitter for iPhone              RT @realDonaldTrump: Rigged Election!
# 72      Twitter for iPhone                            https://t.co/58ssX7EfUj
# 73      Twitter for iPhone  Volunteer to be a Trump Election Poll Watcher....
# ...                    ...                                                ...
# 27059  Twitter for Android  Well the year has officially begun. I have man...
# 27060  Twitter for Android  @sprinklermanus: @CNN @realDonaldTrump they're...
# 27061  Twitter for Android  @jallenaip: Hillary said she was in a Fog of W...
# 27062   Twitter for iPhone  Happy New Year from #MarALago! Thank you to my...
# 27063   Twitter for iPhone      #HappyNewYearAmerica! https://t.co/EeQb8PDrUe
#
#                created_at  retweet_count  favorite_count is_retweet  \
# 69    2020-09-29 23:57:50          75761          321378      False
# 70    2020-09-29 22:51:43          30926               0       True
# 71    2020-09-29 22:37:44          66647               0       True
# 72    2020-09-29 22:35:11          20658           65014      False
# 73    2020-09-29 22:30:39          14609           48540      False
# ...                   ...            ...             ...        ...
# 27059 2016-01-01 18:00:09           2642            8495      False
# 27060 2016-01-01 16:29:56            933            3330      False
# 27061 2016-01-01 01:08:06           2721            7490      False
# 27062 2016-01-01 01:07:28           1948            8258      False
# 27063 2016-01-01 00:18:23           3434            9143      False
#
#                     id_str
# 69     1311153253472636928
# 70     1311136617327984640
# 71     1311133095651717123
# 72     1311132452853706752
# 73     1311131311965306885
# ...                    ...
# 27059   683060169677344768
# 27060   683037464504745985
# 27061   682805477168779264
# 27062   682805320217980929
# 27063   682792967736848385
#
# [26995 rows x 7 columns]

# %% [markdown]
# ### remove links

# %%
import re

# %%
def remove_links(row):
    tweet = row['text']
    tweet = re.sub(r"http\S+", "", tweet)
    return tweet

# %%
trump_tweets['text'] = trump_tweets.apply(remove_links, axis=1)

# %%
trump_tweets
# Out:
#                     source                                               text  \
# 69      Twitter for iPhone
# 70      Twitter for iPhone  RT @TyCardon: Regardless who you’re pulling fo...
# 71      Twitter for iPhone              RT @realDonaldTrump: Rigged Election!
# 72      Twitter for iPhone
# 73      Twitter for iPhone  Volunteer to be a Trump Election Poll Watcher....
# ...                    ...                                                ...
# 27059  Twitter for Android  Well the year has officially begun. I have man...
# 27060  Twitter for Android  @sprinklermanus: @CNN @realDonaldTrump they're...
# 27061  Twitter for Android  @jallenaip: Hillary said she was in a Fog of W...
# 27062   Twitter for iPhone  Happy New Year from #MarALago! Thank you to my...
# 27063   Twitter for iPhone                             #HappyNewYearAmerica!
#
#                created_at  retweet_count  favorite_count is_retweet  \
# 69    2020-09-29 23:57:50          75761          321378      False
# 70    2020-09-29 22:51:43          30926               0       True
# 71    2020-09-29 22:37:44          66647               0       True
# 72    2020-09-29 22:35:11          20658           65014      False
# 73    2020-09-29 22:30:39          14609           48540      False
# ...                   ...            ...             ...        ...
# 27059 2016-01-01 18:00:09           2642            8495      False
# 27060 2016-01-01 16:29:56            933            3330      False
# 27061 2016-01-01 01:08:06           2721            7490      False
# 27062 2016-01-01 01:07:28           1948            8258      False
# 27063 2016-01-01 00:18:23           3434            9143      False
#
#                     id_str
# 69     1311153253472636928
# 70     1311136617327984640
# 71     1311133095651717123
# 72     1311132452853706752
# 73     1311131311965306885
# ...                    ...
# 27059   683060169677344768
# 27060   683037464504745985
# 27061   682805477168779264
# 27062   682805320217980929
# 27063   682792967736848385
#
# [26995 rows x 7 columns]

# %% [markdown]
# ### extract hashtags

# %%
# create a new column to store the hashtags
trump_tweets['hashtag'] = trump_tweets['text'].apply(lambda x: re.findall(r'\B#\w*[a-zA-Z]+\w*', x))

# %%
trump_tweets
# Out:
#                     source                                               text  \
# 69      Twitter for iPhone
# 70      Twitter for iPhone  RT @TyCardon: Regardless who you’re pulling fo...
# 71      Twitter for iPhone              RT @realDonaldTrump: Rigged Election!
# 72      Twitter for iPhone
# 73      Twitter for iPhone  Volunteer to be a Trump Election Poll Watcher....
# ...                    ...                                                ...
# 27059  Twitter for Android  Well the year has officially begun. I have man...
# 27060  Twitter for Android  @sprinklermanus: @CNN @realDonaldTrump they're...
# 27061  Twitter for Android  @jallenaip: Hillary said she was in a Fog of W...
# 27062   Twitter for iPhone  Happy New Year from #MarALago! Thank you to my...
# 27063   Twitter for iPhone                             #HappyNewYearAmerica!
#
#                created_at  retweet_count  favorite_count is_retweet  \
# 69    2020-09-29 23:57:50          75761          321378      False
# 70    2020-09-29 22:51:43          30926               0       True
# 71    2020-09-29 22:37:44          66647               0       True
# 72    2020-09-29 22:35:11          20658           65014      False
# 73    2020-09-29 22:30:39          14609           48540      False
# ...                   ...            ...             ...        ...
# 27059 2016-01-01 18:00:09           2642            8495      False
# 27060 2016-01-01 16:29:56            933            3330      False
# 27061 2016-01-01 01:08:06           2721            7490      False
# 27062 2016-01-01 01:07:28           1948            8258      False
# 27063 2016-01-01 00:18:23           3434            9143      False
#
#                     id_str                   hashtag
# 69     1311153253472636928                        []
# 70     1311136617327984640                        []
# 71     1311133095651717123                        []
# 72     1311132452853706752                        []
# 73     1311131311965306885  [#MakeAmericaGreatAgain]
# ...                    ...                       ...
# 27059   683060169677344768                        []
# 27060   683037464504745985                        []
# 27061   682805477168779264                        []
# 27062   682805320217980929               [#MarALago]
# 27063   682792967736848385    [#HappyNewYearAmerica]
#
# [26995 rows x 8 columns]

# %% [markdown]
# ### extract mentions

# %%
# extract mentions
# for retweets, this regex expression only extracts mentions, but ignores the user handle of the OP
# e.g. the regex expression on "RT @realDonaldTrump: Biden for resident! @JoeBiden" will extract @JoeBiden but not @realDonaldTrump
# as @realDonaldTrump is the OP of the tweet that has been retweeted, rather than a direct mention in the retweet.
trump_tweets['mention'] = trump_tweets['text'].apply(lambda x: re.findall(r'(?<!RT\s)@[a-zA-Z0-9]{1,15}', x))

# %%
trump_tweets
# Out:
#                     source                                               text  \
# 69      Twitter for iPhone
# 70      Twitter for iPhone  RT @TyCardon: Regardless who you’re pulling fo...
# 71      Twitter for iPhone              RT @realDonaldTrump: Rigged Election!
# 72      Twitter for iPhone
# 73      Twitter for iPhone  Volunteer to be a Trump Election Poll Watcher....
# ...                    ...                                                ...
# 27059  Twitter for Android  Well the year has officially begun. I have man...
# 27060  Twitter for Android  @sprinklermanus: @CNN @realDonaldTrump they're...
# 27061  Twitter for Android  @jallenaip: Hillary said she was in a Fog of W...
# 27062   Twitter for iPhone  Happy New Year from #MarALago! Thank you to my...
# 27063   Twitter for iPhone                             #HappyNewYearAmerica!
#
#                created_at  retweet_count  favorite_count is_retweet  \
# 69    2020-09-29 23:57:50          75761          321378      False
# 70    2020-09-29 22:51:43          30926               0       True
# 71    2020-09-29 22:37:44          66647               0       True
# 72    2020-09-29 22:35:11          20658           65014      False
# 73    2020-09-29 22:30:39          14609           48540      False
# ...                   ...            ...             ...        ...
# 27059 2016-01-01 18:00:09           2642            8495      False
# 27060 2016-01-01 16:29:56            933            3330      False
# 27061 2016-01-01 01:08:06           2721            7490      False
# 27062 2016-01-01 01:07:28           1948            8258      False
# 27063 2016-01-01 00:18:23           3434            9143      False
#
#                     id_str                   hashtag  \
# 69     1311153253472636928                        []
# 70     1311136617327984640                        []
# 71     1311133095651717123                        []
# 72     1311132452853706752                        []
# 73     1311131311965306885  [#MakeAmericaGreatAgain]
# ...                    ...                       ...
# 27059   683060169677344768                        []
# 27060   683037464504745985                        []
# 27061   682805477168779264                        []
# 27062   682805320217980929               [#MarALago]
# 27063   682792967736848385    [#HappyNewYearAmerica]
#
#                                          mention
# 69                                            []
# 70                                            []
# 71                                            []
# 72                                            []
# 73                                            []
# ...                                          ...
# 27059                                         []
# 27060  [@sprinklermanus, @CNN, @realDonaldTrump]
# 27061                               [@jallenaip]
# 27062                                         []
# 27063                                         []
#
# [26995 rows x 9 columns]

# %% [markdown]
# ### drop empty text

# %%
# after removal of links, some tweets do not contain any text or only contains empty space. Such occurrences are removed.
# firstly, remove extra white spaces using strip()
trump_tweets['text'] = trump_tweets['text'].apply(lambda x: x.strip())

# %%
# then, drop rows with no content in their tweets
trump_tweets = trump_tweets[trump_tweets.text != '']

# %% [markdown]
# ### reset index

# %%
trump_tweets = trump_tweets.reset_index().drop(columns=['index'])
trump_tweets
# Out:
#                     source                                               text  \
# 0       Twitter for iPhone  RT @TyCardon: Regardless who you’re pulling fo...
# 1       Twitter for iPhone              RT @realDonaldTrump: Rigged Election!
# 2       Twitter for iPhone  Volunteer to be a Trump Election Poll Watcher....
# 3       Twitter for iPhone  “EPA: One Trillion Trees Initiative will build...
# 4       Twitter for iPhone  Joe Biden could not name a single Law Enforcem...
# ...                    ...                                                ...
# 26074  Twitter for Android  Well the year has officially begun. I have man...
# 26075  Twitter for Android  @sprinklermanus: @CNN @realDonaldTrump they're...
# 26076  Twitter for Android  @jallenaip: Hillary said she was in a Fog of W...
# 26077   Twitter for iPhone  Happy New Year from #MarALago! Thank you to my...
# 26078   Twitter for iPhone                              #HappyNewYearAmerica!
#
#                created_at  retweet_count  favorite_count is_retweet  \
# 0     2020-09-29 22:51:43          30926               0       True
# 1     2020-09-29 22:37:44          66647               0       True
# 2     2020-09-29 22:30:39          14609           48540      False
# 3     2020-09-29 22:26:18          10408           36582      False
# 4     2020-09-29 22:15:30           4988           20767      False
# ...                   ...            ...             ...        ...
# 26074 2016-01-01 18:00:09           2642            8495      False
# 26075 2016-01-01 16:29:56            933            3330      False
# 26076 2016-01-01 01:08:06           2721            7490      False
# 26077 2016-01-01 01:07:28           1948            8258      False
# 26078 2016-01-01 00:18:23           3434            9143      False
#
#                     id_str                   hashtag  \
# 0      1311136617327984640                        []
# 1      1311133095651717123                        []
# 2      1311131311965306885  [#MakeAmericaGreatAgain]
# 3      1311130217348345856                        []
# 4      1311127502954196993                        []
# ...                    ...                       ...
# 26074   683060169677344768                        []
# 26075   683037464504745985                        []
# 26076   682805477168779264                        []
# 26077   682805320217980929               [#MarALago]
# 26078   682792967736848385    [#HappyNewYearAmerica]
#
#                                          mention
# 0                                             []
# 1                                             []
# 2                                             []
# 3                                             []
# 4                                             []
# ...                                          ...
# 26074                                         []
# 26075  [@sprinklermanus, @CNN, @realDonaldTrump]
# 26076                               [@jallenaip]
# 26077                                         []
# 26078                                         []
#
# [26079 rows x 9 columns]

# %% [markdown]
# ### save cleaned data

# %%
trump_tweets.to_csv('../data/CLEANED_trump_tweets_20160101_20200930.csv', index=False)
